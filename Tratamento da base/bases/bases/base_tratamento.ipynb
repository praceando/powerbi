# %% [markdown]
# ### Notebook com o objetivo de fazer o tratamento da nossa base formulada por um formulário da microsoft, que foi feito com o objetivo de fazer uma coleta de dados boa e consistente

# %% [markdown]
# ## Importações

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Carregamento da base

# %%
# Carregar o arquivo Excel
df = pd.read_excel('base_antiga.xlsx')

# Exibir as primeiras linhas do DataFrame original
print("Primeiras linhas do DataFrame original:")
print(df.head())
# Out:
# Primeiras linhas do DataFrame original:
#    ID      Hora de início   Hora de conclusão      Email  Nome  \
# 0   1 2024-08-21 08:12:07 2024-08-21 08:17:47  anonymous   NaN
# 1   2 2024-08-21 08:18:47 2024-08-21 08:20:11  anonymous   NaN
# 2   3 2024-08-27 08:15:30 2024-08-27 08:17:09  anonymous   NaN
# 3   4 2024-08-27 09:18:02 2024-08-27 09:22:36  anonymous   NaN
# 4   5 2024-08-27 09:40:13 2024-08-27 09:40:40  anonymous   NaN
#
#    Hora da última modificação Qual é a sua faixa etária?  \
# 0                         NaN          Menor que 18 anos
# 1                         NaN          Menor que 18 anos
# 2                         NaN         Entre 30 e 59 anos
# 3                         NaN         Entre 30 e 59 anos
# 4                         NaN         Entre 18 e 30 anos
#
#   Você mora na cidade de São Paulo  \
# 0                              Sim
# 1                              Sim
# 2                              Sim
# 3                              Sim
# 4                              Sim
#
#   Em que zona da cidade de São Paulo você mora?  \
# 0                                         Oeste
# 1                                         Norte
# 2                                         Norte
# 3                                         Oeste
# 4                                         Norte
#
#   Você costuma organizar ou participar de eventos em praças e parques?  ...  \
# 0                               Participo de eventos                    ...
# 1                               Participo de eventos                    ...
# 2                                             Nenhum                    ...
# 3                                             Nenhum                    ...
# 4                               Participo de eventos                    ...
#
#   Você tem dificuldade em encontrar eventos?  \
# 0                                        Sim
# 1                                        Sim
# 2                                        NaN
# 3                                        NaN
# 4                                        Sim
#
#   Você se considera um microempreendedor?  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
#
#   Como você costuma divulgar seus eventos atualmente? (Selecione todas as opções que se aplicam)  \
# 0                              Não costumo divulgar;
# 1                              Não costumo divulgar;
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Com que frequência você organiza eventos em espaços públicos como praças e parques?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Qual seria a sua disposição para pagar um valor simbólico para anunciar seus eventos em um aplicativo especializado em praças e parques?  \
# 0                                Com certeza pagaria
# 1                        Pagaria dependendo do valor
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Se você utiliza ou utilizaria um aplicativo para promover seus eventos, qual das seguintes funcionalidades seria mais útil para você?  \
# 0          Feedbacks e comentários dos participantes
# 1  Análise de dados sobre seu público (faixa etár...
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   Que tipo de evento você organiza ou participaria em praças ou parques (Selecione todos que se aplicam)  \
# 0            Lazer;Música;Alimentação;Meio Ambiente;
# 1  Música;Lazer;Literatura;Meio Ambiente;Gastrono...
# 2                         Alimentação;Lazer;Esporte;
# 3              Música;Alimentação ;Fotografia;Lazer;
# 4                    Fotografia;Música;Alimentação ;
#
#   Quais fatores são mais importantes para você na escolha de um aplicativo de divulgação de eventos?  \
# 0                                  Facilidade de uso
# 1                                  Facilidade de uso
# 2                                  Facilidade de uso
# 3                                    Custo-benefício
# 4                                  Facilidade de uso
#
#    Você gostaria de ser notificado quando o aplicativo Praceando expandir sua atuação para novas regiões ou oferecer novas funcionalidades?  \
# 0                                                Não
# 1                                                Não
# 2                                                Não
# 3                                                Sim
# 4                                                Não
#
#   Deixe seu e-mail para ser notificado!
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3            danibs2016icloud@gmail com
# 4                                   NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Tratamento da base

# %% [markdown]
# ### Padronização de colunas

# %%
# Padronizar colunas: remover espaços, converter para minúsculas e substituir espaços por "_"
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %% [markdown]
# ### Remoção de colunas irrelevantes

# %%
df.drop(columns=['nome', 'email', 'hora_de_início','hora_de_conclusão', 'hora_da_última_modificação'], inplace=True, errors='ignore')

# %% [markdown]
# ### Remoção de dupliatas

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### Tratamento de valores nulos

# %% [markdown]
# #### Tratamento de colunas específicas

# %%
null_replacements = {
    'você_tem_dificuldade_em_encontrar_eventos?': 'não participa de eventos',
    'você_se_considera_um_microempreendedor?': 'não anuncia eventos',
    'como_você_costuma_divulgar_seus_eventos_atualmente?_(selecione_todas_as_opções_que_se_aplicam)': 'não costuma divulgar',
    'com_que_frequência_você_organiza_eventos_em_espaços_públicos_como_praças_e_parques?': 'não organiza eventos',
    'qual_seria_a_sua_disposição_para_pagar_um_valor_simbólico_para_anunciar_seus_eventos_em_um_aplicativo_especializado_em_praças_e_parques': 'não organiza eventos',
    'se_você_utiliza_ou_utilizaria_um_aplicativo_para_promover_seus_eventos,_qual_das_seguintes_funcionalidades_seria_mais_útil_para_você?': 'não organiza eventos',
    'deixe_seu_e-mail_para_ser_notificado!': 'não gostaria de ser notificado',
    'você_tem_dificuldade_em_divulgar_eventos?': 'não costuma divulgar eventos',
    'você_encontra_dificuldade_em_divulgar_seus_eventos?': 'não costuma divulgar eventos',
    'em_que_zona_da_cidade_de_são_paulo_você_mora': 'não mora na cidade de São Paulo'
}

# Aplicar os valores de substituição para os nulos nas colunas especificadas
for column, replacement in null_replacements.items():
    if column in df.columns:
        df[column].fillna(replacement, inplace=True)
# Out:
# C:\Users\fernandaleao-ieg\AppData\Local\Temp\ipykernel_32020\579557257.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[column].fillna(replacement, inplace=True)

# %% [markdown]
# #### Colunas de texto: Preencher com "Não informado"

# %%
text_columns = df.select_dtypes(include=['object']).columns
for col in text_columns:
    df[col].fillna('Não informado', inplace=True)
# Out:
# C:\Users\fernandaleao-ieg\AppData\Local\Temp\ipykernel_32020\903182732.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna('Não informado', inplace=True)

# %% [markdown]
# #### Padronizar valores de texto nas colunas de texto (remover espaços e converter para minúsculas)

# %%
for col in text_columns:
    df[col] = df[col].str.strip().str.lower()

# %% [markdown]
# #### Verificação de inconsistências em colunas específicas (exemplo: colunas de gênero)

# %%
if 'genero' in df.columns:
    df['genero'] = df['genero'].replace({'masculino': 'm', 'feminino': 'f', 'outro': 'o'})
    df['genero'] = df['genero'].apply(lambda x: 'não informado' if x not in ['m', 'f', 'o'] else x)

# %% [markdown]
# ### Exibindo as primeiras linhas do DataFrame tratado

# %%
print("Primeiras linhas do DataFrame tratado:")
display(df)
# Out:
# Primeiras linhas do DataFrame tratado:
#     id qual_é_a_sua_faixa_etária? você_mora_na_cidade_de_são_paulo  \
# 0    1          menor que 18 anos                              sim
# 1    2          menor que 18 anos                              sim
# 2    3         entre 30 e 59 anos                              sim
# 3    4         entre 30 e 59 anos                              sim
# 4    5         entre 18 e 30 anos                              sim
# ..  ..                        ...                              ...
# 87  88         entre 30 e 59 anos                              sim
# 88  89         entre 18 e 30 anos                              sim
# 89  90         entre 18 e 30 anos                              sim
# 90  91         entre 30 e 59 anos                              sim
# 91  92           mais que 60 anos                           osasco
#
#    em_que_zona_da_cidade_de_são_paulo_você_mora?  \
# 0                                          oeste
# 1                                          norte
# 2                                          norte
# 3                                          oeste
# 4                                          norte
# ..                                           ...
# 87                                         norte
# 88                                           sul
# 89                                         oeste
# 90                                        centro
# 91                                 não informado
#
#    você_costuma_organizar_ou_participar_de_eventos_em_praças_e_parques?  \
# 0                                participo de eventos
# 1                                participo de eventos
# 2                                              nenhum
# 3                                              nenhum
# 4                                participo de eventos
# ..                                                ...
# 87                                   organizo eventos
# 88                                              ambos
# 89                                   organizo eventos
# 90                                              ambos
# 91                                   organizo eventos
#
#    você_encontra_dificuldade_em_divulgar_seus_eventos?  \
# 0                        não costuma divulgar eventos
# 1                        não costuma divulgar eventos
# 2                        não costuma divulgar eventos
# 3                        não costuma divulgar eventos
# 4                        não costuma divulgar eventos
# ..                                                ...
# 87                                                sim
# 88                                                sim
# 89                                                sim
# 90                                                sim
# 91                                                sim
#
#    você_tem_dificuldade_em_encontrar_eventos?  \
# 0                                         sim
# 1                                         sim
# 2                    não participa de eventos
# 3                    não participa de eventos
# 4                                         sim
# ..                                        ...
# 87                   não participa de eventos
# 88                   não participa de eventos
# 89                   não participa de eventos
# 90                   não participa de eventos
# 91                   não participa de eventos
#
#    você_se_considera_um_microempreendedor?  \
# 0                      não anuncia eventos
# 1                      não anuncia eventos
# 2                      não anuncia eventos
# 3                      não anuncia eventos
# 4                      não anuncia eventos
# ..                                     ...
# 87                                     sim
# 88                                     sim
# 89                                     sim
# 90                                     sim
# 91                                     sim
#
#    como_você_costuma_divulgar_seus_eventos_atualmente?_(selecione_todas_as_opções_que_se_aplicam)  \
# 0                               não costumo divulgar;
# 1                               não costumo divulgar;
# 2                                não costuma divulgar
# 3                                não costuma divulgar
# 4                                não costuma divulgar
# ..                                                ...
# 87  redes sociais (instagram, facebook, etc.);boca...
# 88                                  panfletos/flyers;
# 89                                    sites ou blogs;
# 90         redes sociais (instagram, facebook, etc.);
# 91                      boca a boca;panfletos/flyers;
#
#    com_que_frequência_você_organiza_eventos_em_espaços_públicos_como_praças_e_parques?  \
# 0                                não organiza eventos
# 1                                não organiza eventos
# 2                                não organiza eventos
# 3                                não organiza eventos
# 4                                não organiza eventos
# ..                                                ...
# 87           frequentemente (7 ou mais vezes por ano)
# 88                 ocasionalmente (3-6 vezes por ano)
# 89           frequentemente (7 ou mais vezes por ano)
# 90                 ocasionalmente (3-6 vezes por ano)
# 91           frequentemente (7 ou mais vezes por ano)
#
#    qual_seria_a_sua_disposição_para_pagar_um_valor_simbólico_para_anunciar_seus_eventos_em_um_aplicativo_especializado_em_praças_e_parques?  \
# 0                                 com certeza pagaria
# 1                         pagaria dependendo do valor
# 2                                       não informado
# 3                                       não informado
# 4                                       não informado
# ..                                                ...
# 87                        pagaria dependendo do valor
# 88                                com certeza pagaria
# 89                                com certeza pagaria
# 90                                com certeza pagaria
# 91                        pagaria dependendo do valor
#
#    se_você_utiliza_ou_utilizaria_um_aplicativo_para_promover_seus_eventos,_qual_das_seguintes_funcionalidades_seria_mais_útil_para_você?  \
# 0           feedbacks e comentários dos participantes
# 1   análise de dados sobre seu público (faixa etár...
# 2                                não organiza eventos
# 3                                não organiza eventos
# 4                                não organiza eventos
# ..                                                ...
# 87  calendário para organizar e visualizar seus ev...
# 88  calendário para organizar e visualizar seus ev...
# 89  calendário para organizar e visualizar seus ev...
# 90  calendário para organizar e visualizar seus ev...
# 91  calendário para organizar e visualizar seus ev...
#
#    que_tipo_de_evento_você_organiza_ou_participaria_em_praças_ou_parques_(selecione_todos_que_se_aplicam)  \
# 0             lazer;música;alimentação;meio ambiente;
# 1   música;lazer;literatura;meio ambiente;gastrono...
# 2                          alimentação;lazer;esporte;
# 3               música;alimentação ;fotografia;lazer;
# 4                     fotografia;música;alimentação ;
# ..                                                ...
# 87                     lazer;alimentação ;fotografia;
# 88                       lazer;literatura;fotografia;
# 89                       esporte;meio ambiente;lazer;
# 90                           alimentação ;literatura;
# 91                                             lazer;
#
#    quais_fatores_são_mais_importantes_para_você_na_escolha_de_um_aplicativo_de_divulgação_de_eventos?  \
# 0                                   facilidade de uso
# 1                                   facilidade de uso
# 2                                   facilidade de uso
# 3                                     custo-benefício
# 4                                   facilidade de uso
# ..                                                ...
# 87                                  facilidade de uso
# 88                                 alcance do público
# 89                                 alcance do público
# 90                                 alcance do público
# 91                                  facilidade de uso
#
#    você_gostaria_de_ser_notificado_quando_o_aplicativo_praceando_expandir_sua_atuação_para_novas_regiões_ou_oferecer_novas_funcionalidades?  \
# 0                                                 não
# 1                                                 não
# 2                                                 não
# 3                                                 sim
# 4                                                 não
# ..                                                ...
# 87                                                sim
# 88                                                sim
# 89                                                sim
# 90                                                sim
# 91                                                sim
#
#    deixe_seu_e-mail_para_ser_notificado!
# 0         não gostaria de ser notificado
# 1         não gostaria de ser notificado
# 2         não gostaria de ser notificado
# 3             danibs2016icloud@gmail com
# 4         não gostaria de ser notificado
# ..                                   ...
# 87           leaoleitefernanda@gmail.com
# 88           leaoleitefernanda@gmail.com
# 89           leaoleitefernanda@gmail.com
# 90           leaoleitefernanda@gmail.com
# 91           leaoleitefernanda@gmail.com
#
# [92 rows x 16 columns]

# %% [markdown]
# ## Salvando nossa base tratada

# %%
# Salvar o DataFrame tratado em um novo arquivo Excel
df.to_excel('base_tratada.xlsx', index=False)

print(f"Arquivo tratado completo salvo em {'base_tratada.xlsx'}")
# Out:
# Arquivo tratado completo salvo em base_tratada.xlsx
